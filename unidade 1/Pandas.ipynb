# %%
import numpy as np
import pandas as pd

# %%
dados = np.random.randn(5,4)
colunas = ['Coluna 1', 'Coluna 2', 'Coluna 3', 'Coluna 4']
df = pd.DataFrame(dados, columns=colunas)

# %%
df
# Out:
#    Coluna 1  Coluna 2  Coluna 3  Coluna 4
# 0  0.739817  0.458187  0.157743  1.591024
# 1 -1.282953  3.140122  0.774476  2.197032
# 2  0.496990 -0.695501  0.072750  0.308782
# 3  2.092287 -1.120926  0.705005 -0.146432
# 4  1.414080 -0.321197  0.644359  0.243592

# %%
df.describe()
# Out:
#        Coluna 1  Coluna 2  Coluna 3  Coluna 4  Coluna 5
# count  5.000000  5.000000  5.000000  5.000000  5.000000
# mean   0.692044  0.292137  0.470867  0.838800  1.162911
# std    1.267178  1.694620  0.329258  1.002061  1.293153
# min   -1.282953 -1.120926  0.072750 -0.146432 -0.508477
# 25%    0.496990 -0.695501  0.157743  0.243592  0.569740
# 50%    0.739817 -0.321197  0.644359  0.308782  0.897560
# 75%    1.414080  0.458187  0.705005  1.591024  2.058439
# max    2.092287  3.140122  0.774476  2.197032  2.797293

# %%
df.head(3)
# Out:
#    Coluna 1  Coluna 2  Coluna 3  Coluna 4  Coluna 5
# 0  0.739817  0.458187  0.157743  1.591024  0.897560
# 1 -1.282953  3.140122  0.774476  2.197032 -0.508477
# 2  0.496990 -0.695501  0.072750  0.308782  0.569740

# %%
df['Coluna 2']
# Out:
# 0    0.458187
# 1    3.140122
# 2   -0.695501
# 3   -1.120926
# 4   -0.321197
# Name: Coluna 2, dtype: float64

# %%
df[['Coluna 2', 'Coluna 4']]
# Out:
#    Coluna 2  Coluna 4
# 0  0.458187  1.591024
# 1  3.140122  2.197032
# 2 -0.695501  0.308782
# 3 -1.120926 -0.146432
# 4 -0.321197  0.243592

# %%
df['Coluna 1'] + df['Coluna 3']
# Out:
# 0    0.897560
# 1   -0.508477
# 2    0.569740
# 3    2.797293
# 4    2.058439
# dtype: float64

# %%
df['Coluna 5'] = df['Coluna 1'] + df['Coluna 3']
df
# Out:
#    Coluna 1  Coluna 2  Coluna 3  Coluna 4  Coluna 5
# 0  0.739817  0.458187  0.157743  1.591024  0.897560
# 1 -1.282953  3.140122  0.774476  2.197032 -0.508477
# 2  0.496990 -0.695501  0.072750  0.308782  0.569740
# 3  2.092287 -1.120926  0.705005 -0.146432  2.797293
# 4  1.414080 -0.321197  0.644359  0.243592  2.058439

# %%
df.loc[3]
# Out:
# Coluna 1    2.092287
# Coluna 2   -1.120926
# Coluna 3    0.705005
# Coluna 4   -0.146432
# Coluna 5    2.797293
# Name: 3, dtype: float64

# %%
df.iloc[2]
# Out:
# Coluna 1    0.496990
# Coluna 2   -0.695501
# Coluna 3    0.072750
# Coluna 4    0.308782
# Coluna 5    0.569740
# Name: 2, dtype: float64

# %%
df.loc[2, 'Coluna 4']
# Out:
# 0.30878239826482445

# %%
df['Coluna 4'] > 0
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# Name: Coluna 4, dtype: bool

# %%
df[df['Coluna 4']>0]
# Out:
#    Coluna 1  Coluna 2  Coluna 3  Coluna 4  Coluna 5
# 0  0.739817  0.458187  0.157743  1.591024  0.897560
# 1 -1.282953  3.140122  0.774476  2.197032 -0.508477
# 2  0.496990 -0.695501  0.072750  0.308782  0.569740
# 4  1.414080 -0.321197  0.644359  0.243592  2.058439

# %%
df = pd.read_csv('../datas/matogrosso.csv')
df.head()
# Out:
#    NOME_MUNICIPIO   CODIGO          GENTILICO                 PREFEITO2017  \
# 0        Acorizal  5100102          acorizano  CLODOALDO MONTEIRO DA SILVA
# 1        Água Boa  5100201        água-boense          MAURO ROSA DA SILVA
# 2   Alta Floresta  5100250   alta-florestense      ASIEL BEZERRA DE ARAUJO
# 3   Alto Araguaia  5100300         araguaiano     GUSTAVO DE MELO ANICEZIO
# 4  Alto Boa Vista  5100359  alto boa vistense     VALTUIR CANDIDO DA SILVA
#
#        AREA  POPESTIMADA  DENSIDADE  ESCOLARIZACAO   IDHM MORTALIDADE  \
# 0  1014.029         5424       6.56           96.6  0.628       16.13
# 1  7510.635        25229       2.79           99.2  0.729       10.23
# 2  8953.191        51615       5.48           98.0  0.714       19.19
# 3  5399.326        18703       2.84           96.7  0.704        9.09
# 4  2240.438         6659       2.34           96.8  0.651       37.04
#
#        RECEITAS      DESPESAS       PIB
# 0           NaN           NaN  13362.95
# 1   92166.40674   81874.15633  37449.63
# 2  146439.79095  118288.01810  31623.80
# 3   63035.52537   55216.26966  50298.54
# 4   23227.72780   20002.89582  16877.29
